# %%
import cufflinks as cf
cf.go_offline()
import plotly 
import plotly.graph_objects as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected = True)
import plotReportLib
from plotReportLib import myfunctions as fcn
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.11.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
plotly.io.templates.default = "none"
mode_template = go.layout.Template()
mode_template.data.scatter = [
    go.Scatter(
        marker=dict(
            symbol="circle", size=4
        )
    )
]

layout = go.Layout(
xaxis_title='Radius [-]',
yaxis_title='Pressure Fluctuation [-]',
title='Propagating Mode +' + zero_crossings[0],
xaxis=dict(
showline=True , 
showgrid=False,
showticklabels=True,
linecolor='rgb(204, 204, 204)',
linewidth=2 , 
ticks='outside', 
tickfont=dict(
    family='Arial',
size = 12,
color='rgb(82,82,82)',
),
),
yaxis=dict(
showgrid=False,
zeroline=False,
showline=False,
showticklabels=True),
autosize=False,
margin=dict(
autoexpand=True, l=100, r=20, t=110,),
showlegend=True, 
plot_bgcolor='white')

# %%
flow_data    = fcn.importPlotData('../01-mean-flow/mean-flow0032.dat')

# %%
plotly.express.line(
    flow_data,
    x='radius',
    y=['M_x','M_theta'],
    labels={'x':'radius', 'y': 'Flow Velocity [-]'}, title = 'Velocity Profile')

fig = go.Figure()
#fig = go.Figure(layout=layout)
fig.add_trace(go.Scatter(x=flow_data['radius'], y = flow_data['M_x'],
                        mode='lines+markers', name = 'Axial Mach Number'))
fig.add_trace(go.Scatter(x=flow_data['radius'], y = flow_data['M_theta'],
                        mode='lines+markers', name = 'Tangential Mach Number',
                        line=dict(color='firebrick',width=2,dash='dashdot')))
#fig.update_layout(title='Input Velocity Profile',
#                 xaxis_title='Flow Velocity [-]', yaxis_title='Radius [-]')

#    fig.update_layout(
#        template="none",
#        xaxis_title='Radius [-]',
#        yaxis_title='Flow Velocity [-]',
#        title='Input Velocity Profile',
#        xaxis=dict(
#            showline=True , 
#            showgrid=False,
#            showticklabels=True,
#            linecolor='rgb(204, 204, 204)',
#            linewidth=2 , 
#            ticks='outside', 
#            tickfont=dict(
#                family='Arial',
#                size = 12,
#                color='rgb(82,82,82)',
#            ),
#        ),
#        yaxis=dict(
#            showgrid=False,
#            zeroline=False,
#            showline=False,
#            showticklabels=True),
#        autosize=False,
#        margin=dict(
#            autoexpand=False, l=100, r=20, t=110,),
#        showlegend=True, 
#        plot_bgcolor='white')

# %%
directory_32  ='../04-EVanalysis/SWIRLVerification/Table4_3/32pts/'
directory_64  ='../04-EVanalysis/SWIRLVerification/Table4_3/64pts/'
directory_128 ='../04-EVanalysis/SWIRLVerification/Table4_3/128pts/'
directory_256 ='../04-EVanalysis/SWIRLVerification/Table4_3/256pts/'
zero_crossings = ['0']
propagation_index_32 = ['0034', '0033', '0031', '0029', '0027', '0025', '0023', 
                        '0064', '0062', '0060', '0058', '0056', '0054', '0052']

propagation_index_64 = ['0068', '0067', '0065', '0063', '0061', '0059', '0055', '0053', '0051',
                        '0128', '0126', '0124', '0122', '0120', '0118', '0116', '0114', '0113']

propagation_index_128 = ['0234', '0233', '0231', '0229', '0227', '0223', '0213', '0119','0117' ,
                         '0256', '0254', '0252', '0250', '0248', '0246', '0244', '0242','0240' ]

propagation_index_256 = ['0494', '0493', '0491', '0489', '0487', '0485', '0481', '0477', '0473','0451',
                         '0512', '0510', '0508', '0506', '0504', '0502', '0500', '0498', '0496', '0467']
egvfile_32 = []
egvfile_64 = []
egvfile_128 = []
egvfile_256 = []
for i in range(len(propagation_index_32)):
    egvfile_32.append(directory_32 + 'egv.'+  propagation_index_32[i])
    
for i in range(len(propagation_index_64)):
    egvfile_64.append(directory_64 + 'egv.'+  propagation_index_64[i])
    
for i in range(len(propagation_index_128)):
    egvfile_128.append(directory_128 + 'egv.'+  propagation_index_128[i])

for i in range(len(propagation_index_256)):
    egvfile_256.append(directory_256 + 'egv.'+  propagation_index_256[i])
# Out:
# ['../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0034', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0033', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0031', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0029', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0027', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0025', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0023', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0064', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0062', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0060', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0058', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0056', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0054', '../04-EVanalysis/SWIRLVerification/Table4_3/32pts/egv.0052']

# %%
mode_data_32  = []
for i in range(len(propagation_index_32):
    mode_data_32.append(
        fcn.importPlotData(
            str(egvfile_32 [i])
        )
    )
print(mode_data_32)

mode_data_64  = fcn.importPlotData(str(egvfile_64 [0]))
mode_data_128 = fcn.importPlotData(str(egvfile_128[0]))
mode_data_256 = fcn.importPlotData(str(egvfile_256[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-b8039ba9196c> in <module>
#       1 mode_data_32  = []
# ----> 2 for i in range(len(propagation_index_32)/2):
#       3     mode_data_32.append(
#       4         fcn.importPlotData(
#       5             str(egvfile_32 [i])
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
#fig = go.Figure()
fig = plotly.subplots.make_subplots(rows=2, cols=2)
fig.update_layout(template=mode_template)
fig.add_trace(
    go.Scatter(
        x = mode_data_32['Rad'],
        y = mode_data_32['p_no_phase[Re]'],
        mode='markers',
        name = '32',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x = mode_data_64['Rad'],
        y = mode_data_64['p_no_phase[Re]'],
        mode='markers', 
        name = '64',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x    = mode_data_128['Rad'],
        y    = mode_data_128['p_no_phase[Re]'],
        mode ='markers', 
        name = '128',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x    = mode_data_256['Rad'],
        y    = mode_data_256['p_no_phase[Re]'],
        mode = 'markers', 
        name = '256',
    ),
    row = 1, col = 1,
)

#fig = go.Figure()
fig = plotly.subplots.make_subplots(rows=2, cols=2)
fig.update_layout(template=mode_template)
fig.add_trace(
    go.Scatter(
        x = mode_data_32['Rad'],
        y = mode_data_32['p_no_phase[Re]'],
        mode='markers',
        name = '32',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x = mode_data_64['Rad'],
        y = mode_data_64['p_no_phase[Re]'],
        mode='markers', 
        name = '64',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x    = mode_data_128['Rad'],
        y    = mode_data_128['p_no_phase[Re]'],
        mode ='markers', 
        name = '128',
    ),
    row = 1, col = 1,
)

fig.add_trace(
    go.Scatter(
        x    = mode_data_256['Rad'],
        y    = mode_data_256['p_no_phase[Re]'],
        mode = 'markers', 
        name = '256',
    ),
    row = 1, col = 1,
)
fig.add_trace(
    go.Scatter(
        x = mode_data_32['Rad'], 
        y = mode_data_32['p_no_phase[Im]'],
        mode ='lines+markers',
        name = '32',
        line=dict(
            width=2,
            dash='dashdot'
        ) 
    ),
    row = 1, col = 2,
)

fig.add_trace(
    go.Scatter(
        x = mode_data_64['Rad'],
        y = mode_data_64['p_no_phase[Im]'],
        mode ='lines+markers',
        name = '64',
        line=dict(
            width=2,
            dash='dashdot'
        )
    ),
    row = 1, col = 2,
) 
fig.add_trace(
    go.Scatter(
        x = mode_data_128['Rad'],
        y = mode_data_128['p_no_phase[Im]'],
        mode ='lines+markers',
        name = '128',
        line=dict(
            width=2,
            dash='dashdot'
        )
    ),
    row = 1, col = 2,
) 

fig.add_trace(
    go.Scatter(
        x = mode_data_256['Rad'],
        y = mode_data_256['p_no_phase[Im]'],
        mode ='lines+markers',
        name = '256',
        line=dict(
            width=2,
            dash='dashdot'
        )
    ),
   row=1, col=2, 
)

# %%
#fig.update_layout(
#xaxis_title='Radius [-]',
#yaxis_title='Pressure Fluctuation [-]',
#title='Propagating Mode +' + zero_crossings[0],
#xaxis=dict(
#showline=True , 
#showgrid=False,
#showticklabels=True,
#linecolor='rgb(204, 204, 204)',
#linewidth=2 , 
#ticks='outside', 
#tickfont=dict(
#    family='Arial',
#size = 12,
#color='rgb(82,82,82)',
#),
#),
#yaxis=dict(
#showgrid=False,
#zeroline=False,
#showline=False,
#showticklabels=True),
#autosize=False,
#margin=dict(
#autoexpand=True, l=100, r=20, t=110,),
#showlegend=True, 
#plot_bgcolor='white')
#fig.show()
