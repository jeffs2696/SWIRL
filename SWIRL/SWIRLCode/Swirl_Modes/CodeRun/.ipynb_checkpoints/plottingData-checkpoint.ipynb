# %%
#Importing pyplot
from matplotlib import pyplot as plt
import numpy as np

data_file = np.genfromtxt("RateOfConvergenceForIntegration.dat", \
                         skip_header=1)

print(data_file)
#Plotting to our canvas
plt.plot(data_file[:,0],data_file[:,1])
plt.yscale("log")

#Showing what we plotted
plt.show()
# Out:
# [[0.6     2.67348]
#  [0.55556 2.67779]
#  [0.52941 1.76994]
#  [0.51515 1.99562]
#  [0.50769 1.99328]
#  [0.50388 1.9955 ]
#  [0.50195 1.99747]
#  [0.50097 1.99866]
#  [0.50049 1.99931]]

# %%
%gnuplot inline svg
set term tikz 
set output 'testingjupygnuplt.tex'
set termopt enhanced
plot "SourceTermData1.dat" using 1:2 with linespoints 

set term svg mouse standalone
plot \
"SourceTermData1.dat" using 1:2 with linespoints , \
"SourceTermData1.dat" using 1:3 with linespoints 

plot \
"SourceTermData2.dat" using 1:2 with linespoints , \
"SourceTermData2.dat" using 1:3 with linespoints 

plot \
"SourceTermData3.dat" using 1:2 with linespoints , \
"SourceTermData3.dat" using 1:3 with linespoints 

plot \
"SourceTermData4.dat" using 1:2 with linespoints , \
"SourceTermData4.dat" using 1:3 with linespoints
# Out:
# Terminal type is now 'tikz'
# Options are 'latex nopreamble color nostandalone nogparrows notikzarrows nogppoints picenvironment nooriginreset bitmap rgbimage noclip notightboundingbox noexternalimages '
#
# Terminal type is now 'svg'
# Options are 'size 600,480 fixed enhanced font 'Arial,12' mousing standalone butt dashlength 1.0 '

# %%
%ls
# Out:
# AxialWavenumbers/   plottingData.ipynb                   SourceTermData1.dat
# CodeRunObj/         plottingGNUconfig/                   SourceTermData2.dat
# inputdecks/         plottingScripts/                     SourceTermData3.dat
# L2OfSoundSpeed.dat  plt                                  SourceTermData4.dat
# L2OfSourceTerm.dat  pythonPlot.py*                       SourceTermData.dat
# Makefile            RateOfConvergenceForIntegration.dat  SourceTermError.dat
# MeanFlowData/       RateOfConvergenceForSourceTerm.dat   swirlF2020*
# MethodOfManufSoln/  README                               testingjupygnuplt.tex
# plotReport/         SoundSpeedError.dat                  test.py
