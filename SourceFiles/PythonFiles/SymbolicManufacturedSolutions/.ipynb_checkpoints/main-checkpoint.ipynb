# %%
# Importing libraries
from fractions import Fraction 
from sympy import *
from sympy.plotting import plot
from sympy.utilities.codegen import codegen
from sympy.utilities.autowrap import autowrap
from sympy.interactive import printing
from numpy import linspace
printing.init_printing(use_latex = True) 
# general libraries
import sympy as sp
import numpy as np
import math
import re
import numpy as np
import matplotlib.pyplot as mpl 
from matplotlib.ticker import MultipleLocator,FormatStrFormatter,MaxNLocator
import helpers as fcn
# custom libraries

# %%
# Defining symbolic variables needed for this code.
# all units are dimensionless! 

# radius, maximum radius, and ratio of specific heats
r, r_max,r_min, kappa = symbols('r r_max r_min kappa')

# arbitrary constants
k = symbols('k', cls=IndexedBase)
one, \
two, \
three\
  = symbols('one two three')
C = symbols('C')
x = symbols('x')

# reduced frequency
ak = symbols('ak')

# imaginary #, Speed of sound, azimuthal mode number, axial wavenumber 
i, A, m, gamma   = symbols('i A m gamma')
v_r, v_t, v_x, p = symbols('v_r v_t v_x p ')
M_t, M_x         = symbols('M_t M_x')
dp_dr, dv_r_dr   = symbols('dp_dr dv_r_dr')
dM_x_dr, dM_t_dr = symbols('dM_x_dr dM_t_dr')

#locations of inflection Points for tanh
r2 , r3  = symbols('r2 r3')
#unused?
j        = symbols('j')

ci = symbols('ci')
eta = symbols('eta')
kappa = symbols('kappa')

# %%
r_min = 0.2
r_max = 1 #warning: this can be overdefined in fortran and may not sync up
A_1 = 0.1 
B_1 = 10
A_2 = A_1
A_3 = A_1
B_2 = B_1
B_3 = B_1

#the magic numbers are temporary, constants will be defined soon
RightKink = \
A_1*sp.tanh(B_1*(r - 1)) \
+ \
A_2*sp.tanh(B_2*(r - 0.75)) + \
A_3*sp.tanh(B_3*(r - 0.5))

LeftKink = \
A_1*sp.tanh(B_1*(1 - 1)) \
+ \
A_2*sp.tanh(B_2*(0.75   - 1)) + \
A_3*sp.tanh(B_3*(0.5    - 1))
             
S_vertical        = 1

A_analytic        = S_vertical + 0.01*LeftKink + 0.01*RightKink 
dA_analytic_dr    = diff(A_analytic,r)
dA_analytic_sq_dr = diff(A_analytic**2,r)

kappa = 1.4 

M_t_analytic      = (r/((kappa - 1)*A_analytic**2)* \
                     (dA_analytic_sq_dr))**0.5
#M_t_analytic = 0.2*fcn.TanhMethod(3,10,r_min,r_max)
# scalar multiplier below
M_x_analytic = 0.3*fcn.TanhMethod(1 ,10,r_min,r_max )

M_total = (M_x_analytic**(2) + M_t_analytic**(2) )**(0.5)

# %%
f =  fcn.TanhMethod(2,10,r_min,r_max)
df = f.diff(r)
r_hat = (r - r_min)/(r_max - r_min)
f_min = f.subs(r,r_min)
f_max = f.subs(r,r_max)

f_min_desired  = 0
f_max_desired  = 0

A_max          = 3*r_hat**2 - 2*r_hat**3
A_min          =  1 - A_max  

del_f_min = (f_min_desired - f_min)
del_f_max = (f_max_desired - f_max)

f_imposed = fcn.ModifiedManufacturedSolution(f_MS          = f, \
                                             f_minBC       = f_min_desired, \
                                             f_maxBC       = f_max_desired, \
                                             f_minMS       = f_min        , \
                                             f_maxMS       = f_max        , \
                                             A_min         = A_min        , \
                                             A_max         = A_max)

# %%
v_t_analytic = fcn.TanhMethod(2,50,r_min,r_max)
v_x_analytic = fcn.TanhMethod(4,200,r_min,r_max)

# v_r and dp_dr need to be zero at the wall!
v_r_analytic = f_imposed

# TODO: Put if statement to allow constantS for functions
dv_r_dr_analytic = v_r_analytic.diff(r) 
dM_x_dr_analytic = M_x_analytic.diff(r)
dM_t_dr_analytic = M_t_analytic.diff(r)

# %%
sigma = r_min
f =fcn.TanhMethod(2,10,r_min,r_max)
df = f.diff(r)

r_hat = (r - r_min)/(r_max - r_min)
f_min = f.subs(r,r_min)
f_max = f.subs(r,r_max)
df_min = df.subs(r,r_min)
df_max = df.subs(r,r_max)

B_min = (1 - sigma)*\
(\
 ((r -  sigma)/((1) - sigma) )   - \
2*((r - sigma)/((1) - sigma))**(2) +\
  ((r - sigma)/((1) - sigma))**(3)  \
)

B_max = (1 - sigma)* \
(\
-1*((r - sigma)/(1 - sigma))**2 +\
  ((r - sigma)/(1 - sigma))**3  \
)

# how do we get this from main.f90
ak = (1)
gamma = (1)
eta = 0 
ci = sp.sqrt(-1)

psi_1 = \
(2/r)*M_t_analytic*v_t_analytic -  \
((kappa - 1)/r)*(M_t_analytic**2)*f - df

psi_2 = dv_r_dr_analytic + ci*gamma*v_x_analytic +\
(((kappa + 1)/(2*r))*M_t_analytic**2 + 1/r)*v_t_analytic

L = eta*((1-(gamma/ak))*M_total)*f

del_dp_BC = psi_1 + L*psi_2 


del_dp_minBC = del_dp_BC.subs({'r':r_min, \
                               'ak':ak,\
                                'eta':eta,\
                                'kappa':kappa,\
                                'ci':ci \
                               })
del_dp_maxBC = del_dp_BC.subs({'r':r_max, \
                                'ak':ak,\
                                'eta':eta,\
                                'kappa':kappa,\
                                'ci':ci \
                               })
                                

p_analytic = fcn.diffModifiedManufacturedSolution(f,del_dp_minBC,del_dp_maxBC,B_min,B_max)
p_analytic = p_analytic.subs({'ak':ak,\
                                  'gamma':gamma,\
                                   'eta':eta,\
                                 'ci':ci})

dp_dr_analytic   = p_analytic.diff(r)

# %%
def plotSymbolicEquation(x_data,y_data,x_min,x_max):
    
    # convert symbolic expressions using numpy
    lam_x = lambdify(x_data,y_data , modules=['numpy'])
    x_vals = linspace((x_min), (x_max), 100)
    y_vals = lam_x(x_vals) 
    
    fig = mpl.figure(figsize=(10,6))
    ax = mpl.axes()
    ax.grid(True,which='major',axis='both',alpha=0.3) 
    mpl.plot(x_vals, y_vals)
    mpl.show(fig)
    
    return fig


plotSymbolicEquation(r,A_analytic  ,r_min,r_max)
plotSymbolicEquation(r,M_t_analytic,r_min,r_max)
plotSymbolicEquation(r,M_x_analytic,r_min,r_max)
plotSymbolicEquation(r,v_r_analytic,r_min,r_max)
plotSymbolicEquation(r,v_t_analytic,r_min,r_max)
plotSymbolicEquation(r,v_x_analytic,r_min,r_max)
plotSymbolicEquation(r,p_analytic,r_min,r_max)
plotSymbolicEquation(r,dp_dr_analytic,r_min,r_max)

# %%
def SourceSubstitution(S, \
                       A_analytic         , \
                       M_t_analytic       , \
                       M_x_analytic     , \
                       v_r_analytic     , \
                       v_t_analytic     , \
                       v_x_analytic     , \
                       p_analytic       , \
                       dp_dr_analytic   , \
                       dv_r_dr_analytic , \
                       dM_x_dr_analytic , \
                       dM_t_dr_analytic , \
                      ): 
    
    print('Input Source: ', S)
    S = S.subs({ \
            A:A_analytic       , \
            M_t:M_t_analytic   , \
            M_x:M_x_analytic , \
            v_r:v_r_analytic , \
            v_t:v_t_analytic , \
            v_x:v_x_analytic , \
            p:p_analytic     , \
            dp_dr:dp_dr_analytic, \
            dv_r_dr:dv_r_dr_analytic, \
            dM_x_dr:dM_x_dr_analytic, \
            dM_t_dr:dM_t_dr_analytic, \
               })
    print('Output Source', S)
    return S

# %%
S = list(range(4)) 
S[0] = \
-i*(ak/A - (m/r)*M_t - gamma*M_x)*v_r  -\
\
(two/r)*M_t*v_t + dp_dr + ((kappa - one)/r)*(M_t**two)*p

S[1] = \
-i*(ak/A - (m/r)*M_t - gamma*M_x)*v_t + \
\
(M_t/r + dM_t_dr + ((kappa - one)/(two*r))*M_t**three)*v_r + i*m*p/r

S[2] = \
-i*(ak/A - (m/r)*M_t - gamma*M_x)*v_x + \
\
(dM_x_dr + ((kappa - one)/(two*r))*M_x*M_t**two)*v_r + i*one*gamma*p
 
S[3] = \
-i*(ak/A - (m/r)*M_t - gamma*M_x)*p   \
\
+ dv_r_dr + (((kappa + one)/(two*r))*M_t**two + one/r)*v_r + i*m*v_t/r + i*one*gamma*v_x

# %%
AA = sp.Matrix(sp.zeros(4,4))

AA[0,0] = -i*(ak/A - (m/r)*M_t)
AA[1,1] = AA[0,0]
AA[2,2] = AA[0,0]
AA[3,3] = AA[0,0]

AA[0,2] = 0
AA[1,2] = 0
AA[3,2] = 0
AA[2,1] = 0
AA[2,3] = 0

AA[1,3] = (i*m)/r
AA[3,1] = AA[1,3]

A12 = (-two/r)*M_t
A21 = M_t/r + dM_t_dr + (kappa - one)/(two*r)*M_t**three
A31 = dM_x_dr + (kappa - one)/(two*r)*M_t**two*M_x

AA[0,1] = A12
AA[1,0] = A21
AA[2,0] = A31

# note that these terms only have derivative operators , See Eqn 2.52

A41 = (1/v_r)*dv_r_dr + one/r + (kappa + one)/(two*r)*M_t**two
A14 = (1/p)*dp_dr + (kappa - one)/r * M_t**two

AA[3,0] = A41
AA[0,3] = A14

BB = sp.zeros(4,4)

BB[0,0] = M_x
BB[1,1] = BB[0,0]
BB[2,2] = BB[0,0]
BB[3,3] = BB[0,0]

BB[2,3] = one
BB[3,2] = BB[2,3]

XX = sp.Matrix([\
               [v_r] , \
               [v_t] , \
               [v_x] , \
               [p] , \
               ])

Lambda = -i*gamma

SS = AA*XX - Lambda*BB*XX

# %%
#now that we set the matricies up lets get our individual terms 
A_times_x        = sp.Matrix(sp.zeros(len(S),len(S)))
lambda_B_times_x = sp.Matrix(sp.zeros(len(S),len(S)))

for j in range(len(S)):
    for i in range(len(S)):
        A_times_x[i,j]        = [AA[i,j]*XX[j]]
        lambda_B_times_x[i,j] = Lambda*BB[i,j]*XX[j]

for i in range(len(S)):
    match =(S[i].equals( \
                  A_times_x[i,0] + \
                  A_times_x[i,1] + \
                  A_times_x[i,2] + \
                  A_times_x[i,3] -\
                 (lambda_B_times_x[i,0] + \
                  lambda_B_times_x[i,1] + \
                  lambda_B_times_x[i,2] + \
                  lambda_B_times_x[i,3])))
    print(match)
# notes on differences between system of equations and Ax-lambda Bx    
# multiplying (1/p) and not (one/p) by dp_dr made  S_1 and SS[1] the same
# multiplied i gamma p term by "one" in S_3
# multiplied by 1/v_r by d_v_dr and i v_x gamma terM by one
# Out:
# True
# True
# True
# True

# %%
# Checking if the matrix expressions equal the linear system of equations
print(S[0].equals(SS[0]))
print(S[1].equals(SS[1]))
print(S[2].equals(SS[2]))
print(S[3].equals(SS[3]))

for i in range(len(S)):
    S[i] = SourceSubstitution(S[i], \
                       A_analytic         , \
                       M_t_analytic   , \
                       M_x_analytic     , \
                       v_r_analytic     , \
                       v_t_analytic     , \
                       v_x_analytic     , \
                       p_analytic       , \
                       dp_dr_analytic   , \
                       dv_r_dr_analytic , \
                       dM_x_dr_analytic , \
                       dM_t_dr_analytic , \
                       )

for i in range(len(A_times_x[:,0])):
    for j in range(len(A_times_x[0,:])):
        A_times_x[i,j] = SourceSubstitution(\
                       A_times_x[i,j], \
                       A_analytic         , \
                       M_t_analytic   , \
                       M_x_analytic     , \
                       v_r_analytic     , \
                       v_t_analytic     , \
                       v_x_analytic     , \
                       p_analytic       , \
                       dp_dr_analytic   , \
                       dv_r_dr_analytic , \
                       dM_x_dr_analytic , \
                       dM_t_dr_analytic , \
                                      ) 
        lambda_B_times_x[i,j] = SourceSubstitution(\
                       lambda_B_times_x[i,j], \
                       A_analytic         , \
                       M_t_analytic   , \
                       M_x_analytic     , \
                       v_r_analytic     , \
                       v_t_analytic     , \
                       v_x_analytic     , \
                       p_analytic       , \
                       dp_dr_analytic   , \
                       dv_r_dr_analytic , \
                       dM_x_dr_analytic , \
                       dM_t_dr_analytic , \
                                         )
# Out:
# True
# True
# True
# True
# Input Source:  -M_t*two*v_t/r + M_t**two*p*(1.4 - one)/r + dp_dr - i*v_r*(-M_t*m/r - M_x + 1/A)
# Output Source -i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r - 0.1125*tanh(12.5*r - 12.5) - 0.3 + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423) + 22.1066481990497*r - 27.0352357616045*(r - 0.2)**2 - 3.125*tanh(12.5*r - 12.5)**2 - 3.125*tanh(12.5*r - 2.5)**2 - 1.24647195695418 - 1.58113883008419*two*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)/r + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(1.4 - one)*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)/r
# Input Source:  i*m*p/r - i*v_t*(-M_t*m/r - M_x + 1/A) + v_r*(M_t/r + M_t**three*(1.4 - one)/(r*two) + dM_t_dr)
# Output Source i*m*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)/r - i*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r - 0.1125*tanh(12.5*r - 12.5) - 0.3 + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586)) + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5*(0.5*r*(-0.0200398095526603*(20 - 20*tanh(10*r - 10)**2)*tanh(10*r - 10) - 0.0200398095526603*(20 - 20*tanh(10*r - 7.5)**2)*tanh(10*r - 7.5) - 0.0200398095526603*(20 - 20*tanh(10*r - 5.0)**2)*tanh(10*r - 5.0))/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1) + 0.5*r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)*(0.0100199047763301*tanh(10*r - 10)**2 + 0.0100199047763301*tanh(10*r - 7.5)**2 + 0.0100199047763301*tanh(10*r - 5.0)**2 - 0.0300597143289904)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1)**2 + 0.5*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))*(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1)/(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)) + 1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**three*(1.4 - one)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  i*one*p - i*v_x*(-M_t*m/r - M_x + 1/A) + v_r*(M_t**two*M_x*(1.4 - one)/(r*two) + dM_x_dr)
# Output Source i*one*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942) - i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r - 0.1125*tanh(12.5*r - 12.5) - 0.3 + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(0.15*tanh(250.0*r - 250.0) + 0.15*tanh(250.0*r - 183.333333333333) + 0.15*tanh(250.0*r - 116.666666666667) + 0.15*tanh(250.0*r - 50.0) + 0.55) + (-1.40625*tanh(12.5*r - 12.5)**2 + 1.40625 + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(1.4 - one)*(0.1125*tanh(12.5*r - 12.5) + 0.3)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  dv_r_dr + i*m*v_t/r + i*one*v_x - i*p*(-M_t*m/r - M_x + 1/A) + v_r*(M_t**two*(one + 1.4)/(r*two) + one/r)
# Output Source i*m*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)/r + i*one*(0.15*tanh(250.0*r - 250.0) + 0.15*tanh(250.0*r - 183.333333333333) + 0.15*tanh(250.0*r - 116.666666666667) + 0.15*tanh(250.0*r - 50.0) + 0.55) - i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r - 0.1125*tanh(12.5*r - 12.5) - 0.3 + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942) - 4.68749998067668*r + 5.85937497584586*(r - 0.2)**2 + (one/r + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(one + 1.4)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423) - 3.125*tanh(12.5*r - 12.5)**2 - 3.125*tanh(12.5*r - 2.5)**2 + 7.18749999613534
# Input Source:  -i*v_r*(-M_t*m/r + 1/A)
# Output Source -i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  -M_x*i*v_r
# Output Source -i*(0.1125*tanh(12.5*r - 12.5) + 0.3)*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  -M_t*two*v_t/r
# Output Source -1.58113883008419*two*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)/r
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  p*(M_t**two*(1.4 - one)/r + dp_dr/p)
# Output Source ((22.1066481990497*r - 27.0352357616045*(r - 0.2)**2 - 3.125*tanh(12.5*r - 12.5)**2 - 3.125*tanh(12.5*r - 2.5)**2 - 1.24647195695418)/(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942) + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(1.4 - one)/r)*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)
# Input Source:  0
# Output Source 0
# Input Source:  v_r*(M_t/r + M_t**three*(1.4 - one)/(r*two) + dM_t_dr)
# Output Source (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5*(0.5*r*(-0.0200398095526603*(20 - 20*tanh(10*r - 10)**2)*tanh(10*r - 10) - 0.0200398095526603*(20 - 20*tanh(10*r - 7.5)**2)*tanh(10*r - 7.5) - 0.0200398095526603*(20 - 20*tanh(10*r - 5.0)**2)*tanh(10*r - 5.0))/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1) + 0.5*r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)*(0.0100199047763301*tanh(10*r - 10)**2 + 0.0100199047763301*tanh(10*r - 7.5)**2 + 0.0100199047763301*tanh(10*r - 5.0)**2 - 0.0300597143289904)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1)**2 + 0.5*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))*(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1)/(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)) + 1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**three*(1.4 - one)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  0
# Output Source 0
# Input Source:  -i*v_t*(-M_t*m/r + 1/A)
# Output Source -i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)
# Input Source:  -M_x*i*v_t
# Output Source -i*(0.1125*tanh(12.5*r - 12.5) + 0.3)*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  i*m*p/r
# Output Source i*m*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)/r
# Input Source:  0
# Output Source 0
# Input Source:  v_r*(M_t**two*M_x*(1.4 - one)/(r*two) + dM_x_dr)
# Output Source (-1.40625*tanh(12.5*r - 12.5)**2 + 1.40625 + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(1.4 - one)*(0.1125*tanh(12.5*r - 12.5) + 0.3)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  -i*v_x*(-M_t*m/r + 1/A)
# Output Source -i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(0.15*tanh(250.0*r - 250.0) + 0.15*tanh(250.0*r - 183.333333333333) + 0.15*tanh(250.0*r - 116.666666666667) + 0.15*tanh(250.0*r - 50.0) + 0.55)
# Input Source:  -M_x*i*v_x
# Output Source -i*(0.1125*tanh(12.5*r - 12.5) + 0.3)*(0.15*tanh(250.0*r - 250.0) + 0.15*tanh(250.0*r - 183.333333333333) + 0.15*tanh(250.0*r - 116.666666666667) + 0.15*tanh(250.0*r - 50.0) + 0.55)
# Input Source:  0
# Output Source 0
# Input Source:  -i*one*p
# Output Source -i*one*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)
# Input Source:  v_r*(M_t**two*(one + 1.4)/(r*two) + dv_r_dr/v_r + one/r)
# Output Source (one/r + (-4.68749998067668*r + 5.85937497584586*(r - 0.2)**2 - 3.125*tanh(12.5*r - 12.5)**2 - 3.125*tanh(12.5*r - 2.5)**2 + 7.18749999613534)/(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423) + (1.58113883008419*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5)**two*(one + 1.4)/(r*two))*(1.95312499194862*(r - 0.2)**3 - 2.34374999033834*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 0.249999998969423)
# Input Source:  0
# Output Source 0
# Input Source:  i*m*v_t/r
# Output Source i*m*(0.25*tanh(62.5*r - 62.5) + 0.25*tanh(62.5*r - 12.5) + 0.75)/r
# Input Source:  0
# Output Source 0
# Input Source:  0
# Output Source 0
# Input Source:  -i*one*v_x
# Output Source -i*one*(0.15*tanh(250.0*r - 250.0) + 0.15*tanh(250.0*r - 183.333333333333) + 0.15*tanh(250.0*r - 116.666666666667) + 0.15*tanh(250.0*r - 50.0) + 0.55)
# Input Source:  -i*p*(-M_t*m/r + 1/A)
# Output Source -i*(-1.58113883008419*m*(r*(-0.0200398095526603*tanh(10*r - 10)**2 - 0.0200398095526603*tanh(10*r - 7.5)**2 - 0.0200398095526603*tanh(10*r - 5.0)**2 + 0.0601194286579808)/(0.00100199047763301*tanh(10*r - 10) + 0.00100199047763301*tanh(10*r - 7.5) + 0.00100199047763301*tanh(10*r - 5.0) + 1))**0.5/r + 1/(0.001*tanh(10*r - 10) + 0.001*tanh(10*r - 7.5) + 0.001*tanh(10*r - 5.0) + 0.998013476497586))*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)
# Input Source:  -M_x*i*p
# Output Source -i*(0.1125*tanh(12.5*r - 12.5) + 0.3)*(-3.07514231714424*r - 9.01174525386818*(r - 0.2)**3 + 11.0533240995248*(r - 0.2)**2 + 0.25*tanh(12.5*r - 12.5) + 0.25*tanh(12.5*r - 2.5) + 1.36502846445942)

# %%
# %run create-fortran-scripts/create-fortran-file-sound-speed.ipynb

# %run create-fortran-scripts/create-fortran-file-perturbation-variables.ipynb

S_1 = S[0]
S_2 = S[1]
S_3 = S[2]
S_4 = S[3]
# %run create-fortran-scripts/create-fortran-file-LEE-source-terms.ipynb

# %run create-fortran-scripts/create-fortran-file-LEE-source-terms-components.ipynb
# Out:
# SoundSpeedMMS.f90 below
#
#
# ! Returns M_theta and the corresponding sound speed as defined in
#
# ! SourceTermSymbolicSolver.ipynb
#
#
#
#     SUBROUTINE CalcSoundSpeed(&
#
#     r                 , &
#
#     k, kappa          , &
#
#     SoundSpeedExpected, &
#
#     thetaMachData     , &
#
#     axialMachData)
#
#
#
#     REAL(KIND=rDef)   , INTENT(IN) :: &
#
#     kappa
#
#
#
#     REAL(KIND=rDef)   , DIMENSION(:), INTENT(INOUT) :: &
#
#     SoundSpeedExpected, thetaMachData, axialMachData
#
#
#
#     REAL(KIND=rDef)   , DIMENSION(:), INTENT(IN) :: &
#
#     r
#
#
#
#     COMPLEX(KIND=rDef), DIMENSION(:), INTENT(IN) :: &
#
#     k
#
#
#
#     ! Local variables
#
#     INTEGER :: &
#
#     numberOfGridPoints, i!, j
#
#
#
#     REAL(KIND = rDef) :: one,two,three
#
#
#
#     REAL(KIND=rDef), DIMENSION(SIZE(k)) :: kR
#
#
#
#     kR = REAL(k,KIND = rDef)
#
#
#
#     one   = (1.0_rDef)
#
#     two   = (2.0_rDef)
#
#     three = (3.0_rDef)
#
#
#
#
#
#     numberOfGridPoints = SIZE(SoundSpeedExpected)
#
#
#
#         DO i = 1,numberOfGridPoints
#
#
#
#         SoundSpeedExpected(i) = 0.001d0*tanh(10.0d0*r(i)- 10.0d0) + 0.001d0*tanh(10.0d0*r(i)- 7.5d0) + &
#
#       0.001d0*tanh(10.0d0*r(i)- 5.0d0) + 0.998013476497586d0
#
#         thetaMachData(i)      = 1.58113883008419d0*sqrt(r(i)*(-0.0200398095526603d0*tanh(10.0d0*r(i)- 10.0d0) &
#
#       **2 - 0.0200398095526603d0*tanh(10.0d0*r(i)- 7.5d0)**2 - &
#
#       0.0200398095526603d0*tanh(10.0d0*r(i)- 5.0d0)**2 + &
#
#       0.0601194286579808d0)/(0.00100199047763301d0*tanh(10.0d0*r(i)- &
#
#       10.0d0) + 0.00100199047763301d0*tanh(10.0d0*r(i)- 7.5d0) + &
#
#       0.00100199047763301d0*tanh(10.0d0*r(i)- 5.0d0) + 1))
#
#         axialMachData(i)      = 0.1125d0*tanh(12.5d0*r(i)- 12.5d0) + 0.3d0
#
#
#
#
#
#         END DO
#
#
#
#     END SUBROUTINE CalcSoundSpeed
