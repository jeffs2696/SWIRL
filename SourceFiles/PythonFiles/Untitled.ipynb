# %%
# %run tanh-method-mms.ipynb

# %%
r = sp.IndexedBase('r')
n = 9 # number of kinks
B = 1000
debug = 0

# %%
f = TanhMethodMMS(n,B)
display(f)
# Out:
# 0.075⋅tanh(1000⋅r - 1000.0) + 0.075⋅tanh(1000⋅r - 875.0) + 0.075⋅tanh(1000⋅r -
#  750.0) + 0.075⋅tanh(1000⋅r - 625.0) + 0.075⋅tanh(1000⋅r - 500.0) + 0.075⋅tanh
# (1000⋅r - 375.0) + 0.075⋅tanh(1000⋅r - 250.0) + 0.075⋅tanh(1000⋅r - 125.0) + 0
# .075⋅tanh(1000⋅r) + 0.4
